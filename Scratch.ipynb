-- %%
show schemas in samples

-- %%
%sql
SELECT *
FROM samples.nyctaxi.trips
LIMIT 10;

-- %%
%sql
SELECT count(1)
FROM samples.nyctaxi.trips

-- %%
select 'tpch_sf1', format_number(count(1), 0) from samples.tpch_sf1.customer
union all 
select 'tpch_sf10', format_number(count(1), 0) from samples.tpch_sf10.customer
union all 
select 'tpch_sf100', format_number(count(1), 0) from samples.tpch_sf100.customer
union all
select 'tpch_sf100', format_number(count(1), 0) from samples.tpch_sf1000.customer

-- %%
select 'tpcds_sf1', format_number(count(1), 0) from samples.tpcds_sf1.customer
union all 
select 'tpcds_sf1000', format_number(count(1), 0) from samples.tpcds_sf1000.customer

-- %%
show tables in samples.tpcds_sf1

-- %%
DESCRIBE DETAIL samples.tpcds_sf1.store_sales;

-- %%
SELECT COUNT(*) AS row_count
FROM samples.tpcds_sf1.store_sales;

-- %%
SELECT *
FROM samples.tpcds_sf1.store_sales
LIMIT 5;
